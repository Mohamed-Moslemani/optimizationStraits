# %% [markdown]
# # Exploration notebook
#
# Scratch space for the straitgraph v1 model.

# %%
from pathlib import Path
from straitgraph.graph import build_graph, load_countries, load_straits
from straitgraph.market import solve_market
from straitgraph.resilience import strait_importance

DATA = Path('..').resolve() / 'data'
g = build_graph(load_countries(DATA / 'countries.csv'), load_straits(DATA / 'straits.csv'))
sol = solve_market(g)
sol.total_cost
